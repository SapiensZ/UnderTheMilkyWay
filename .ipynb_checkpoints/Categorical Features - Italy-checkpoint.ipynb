# %%
# basic operations
import numpy as np
import pandas as pd


# for visualizations
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
# import csv file
df = pd.read_csv("UMW_FR_reduced.csv", sep=",")
imdb = pd.read_csv("IMDB_movies_data_clean.csv", sep=",")
tags = pd.read_csv("tags_clean.csv", sep=",")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (19,20,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
#Define columns of interest
cols_1 = ['original_title', 'royalties_paid_eur']
cols_2 = ['cast', 'genre']
cols = cols_1 + cols_2

# %%
#Group by movies and transform labels
df_revenue = df[cols].groupby('original_title')['royalties_paid_eur'].sum()
df_count = df[cols].groupby('original_title')['royalties_paid_eur'].count()

df_movie = df[['original_title'] + cols_2].drop_duplicates()
df_movie = df_movie.fillna('None')
df_movies = []
for col in cols_2:
    mlb = MultiLabelBinarizer()
    df_movie[col] = df_movie[col].str.split(', ')
    temp1 = pd.DataFrame({'revenue':df_revenue, 'count':df_count})
    temp2 = pd.DataFrame(mlb.fit_transform(df_movie[col]), columns=mlb.classes_, index=df_movie['original_title'])
    temp = temp1.join(temp2)
    df_movies.append(temp)

# %%
# One-hot dataframe with all starred actors
df_cast = df_movies[0]
df_cast
# Out:
#                           revenue  count  ??? ??????  ?????? ???????  \
# original_title
# 1 Buck                1687.222490    300           0               0
# 1 chance 2 dance        37.660000     16           0               0
# 10,000 Saints          728.620000    264           0               0
# 100 Feet              3043.130000   1409           0               0
# 101 Reykjavik          110.320000     64           0               0
# ...                           ...    ...         ...             ...
# Çanakkale Yolun Sonu    66.540000     35           0               0
# Ég Man Þig            3340.530000    803           0               0
# Élève libre            235.115916    100           0               0
# Études sur Paris      4221.530000   1201           0               0
# Über Wasser             10.000000      2           0               0
#
#                       ??????? ???????  ??????? ??????? aka Vtol  \
# original_title
# 1 Buck                              0                         0
# 1 chance 2 dance                    0                         0
# 10,000 Saints                       0                         0
# 100 Feet                            0                         0
# 101 Reykjavik                       0                         0
# ...                               ...                       ...
# Çanakkale Yolun Sonu                0                         0
# Ég Man Þig                          0                         0
# Élève libre                         0                         0
# Études sur Paris                    0                         0
# Über Wasser                         0                         0
#
#                       ???????? ???????  ???????? ??????? aka Benzo  \
# original_title
# 1 Buck                               0                           0
# 1 chance 2 dance                     0                           0
# 10,000 Saints                        0                           0
# 100 Feet                             0                           0
# 101 Reykjavik                        0                           0
# ...                                ...                         ...
# Çanakkale Yolun Sonu                 0                           0
# Ég Man Þig                           0                           0
# Élève libre                          0                           0
# Études sur Paris                     0                           0
# Über Wasser                          0                           0
#
#                       ????????? ??????  ?????·???  ...  Ágnes Bertalan  \
# original_title                                     ...
# 1 Buck                               0          0  ...               0
# 1 chance 2 dance                     0          0  ...               0
# 10,000 Saints                        0          0  ...               0
# 100 Feet                             0          0  ...               0
# 101 Reykjavik                        0          0  ...               0
# ...                                ...        ...  ...             ...
# Çanakkale Yolun Sonu                 0          0  ...               0
# Ég Man Þig                           0          0  ...               0
# Élève libre                          0          0  ...               0
# Études sur Paris                     0          0  ...               0
# Über Wasser                          0          0  ...               0
#
#                       Ágústa Eva Erlendsdóttir  Álvaro Miguel  \
# original_title
# 1 Buck                                       0              0
# 1 chance 2 dance                             0              0
# 10,000 Saints                                0              0
# 100 Feet                                     0              0
# 101 Reykjavik                                0              0
# ...                                        ...            ...
# Çanakkale Yolun Sonu                         0              0
# Ég Man Þig                                   1              0
# Élève libre                                  0              0
# Études sur Paris                             0              0
# Über Wasser                                  0              0
#
#                       Ángela del Salto  Éric ROHMER  Étienne Galloy  \
# original_title
# 1 Buck                               0            0               0
# 1 chance 2 dance                     0            0               0
# 10,000 Saints                        0            0               0
# 100 Feet                             0            0               0
# 101 Reykjavik                        0            0               0
# ...                                ...          ...             ...
# Çanakkale Yolun Sonu                 0            0               0
# Ég Man Þig                           0            0               0
# Élève libre                          0            0               0
# Études sur Paris                     0            0               0
# Über Wasser                          0            0               0
#
#                       Özge Özberk  Özkan Ugur  Özlem Tekin  \
# original_title
# 1 Buck                          0           0            0
# 1 chance 2 dance                0           0            0
# 10,000 Saints                   0           0            0
# 100 Feet                        0           0            0
# 101 Reykjavik                   0           0            0
# ...                           ...         ...          ...
# Çanakkale Yolun Sonu            0           0            0
# Ég Man Þig                      0           0            0
# Élève libre                     0           0            0
# Études sur Paris                0           0            0
# Über Wasser                     0           0            0
#
#                       Þorbjörg Helga Þorgilsdóttir
# original_title
# 1 Buck                                           0
# 1 chance 2 dance                                 0
# 10,000 Saints                                    0
# 100 Feet                                         0
# 101 Reykjavik                                    0
# ...                                            ...
# Çanakkale Yolun Sonu                             0
# Ég Man Þig                                       0
# Élève libre                                      0
# Études sur Paris                                 0
# Über Wasser                                      0
#
# [1333 rows x 3841 columns]

# %%
# One-hot dataframe with all represented genres
df_genre = df_movies[1]
df_genre
# Out:
#                           revenue  count  Action & Adventure  African  Anime  \
# original_title
# 1 Buck                1687.222490    300                   1        0      0
# 1 chance 2 dance        37.660000     16                   0        0      0
# 10,000 Saints          728.620000    264                   0        0      0
# 100 Feet              3043.130000   1409                   0        0      0
# 101 Reykjavik          110.320000     64                   0        0      0
# ...                           ...    ...                 ...      ...    ...
# Çanakkale Yolun Sonu    66.540000     35                   1        0      0
# Ég Man Þig            3340.530000    803                   0        0      0
# Élève libre            235.115916    100                   0        0      0
# Études sur Paris      4221.530000   1201                   0        0      0
# Über Wasser             10.000000      2                   0        0      0
#
#                       Classics  Comedy  Concert Films  Crime  Documentary  \
# original_title
# 1 Buck                       0       0              0      1            0
# 1 chance 2 dance             0       0              0      0            0
# 10,000 Saints                0       1              0      0            0
# 100 Feet                     0       0              0      0            0
# 101 Reykjavik                0       1              0      0            0
# ...                        ...     ...            ...    ...          ...
# Çanakkale Yolun Sonu         0       0              0      0            0
# Ég Man Þig                   0       0              0      0            0
# Élève libre                  0       0              0      0            0
# Études sur Paris             0       0              0      0            1
# Über Wasser                  0       0              0      0            1
#
#                       ...  Sci-Fi & Fantasy  Short Films  Special Interest  \
# original_title        ...
# 1 Buck                ...                 0            0                 0
# 1 chance 2 dance      ...                 0            0                 0
# 10,000 Saints         ...                 0            0                 0
# 100 Feet              ...                 0            0                 0
# 101 Reykjavik         ...                 0            0                 0
# ...                   ...               ...          ...               ...
# Çanakkale Yolun Sonu  ...                 0            0                 0
# Ég Man Þig            ...                 0            0                 0
# Élève libre           ...                 0            0                 0
# Études sur Paris      ...                 0            0                 0
# Über Wasser           ...                 0            0                 0
#
#                       Sports  Suspense  Thriller  Turkish  Urban  War  Western
# original_title
# 1 Buck                     0         0         1        0      0    0        0
# 1 chance 2 dance           0         0         0        0      0    0        0
# 10,000 Saints              0         0         0        0      0    0        0
# 100 Feet                   0         0         1        0      0    0        0
# 101 Reykjavik              0         0         0        0      0    0        0
# ...                      ...       ...       ...      ...    ...  ...      ...
# Çanakkale Yolun Sonu       0         0         0        0      0    0        0
# Ég Man Þig                 0         0         1        0      0    0        0
# Élève libre                0         0         0        0      0    0        0
# Études sur Paris           0         0         0        0      0    0        0
# Über Wasser                0         0         0        0      0    0        0
#
# [1333 rows x 41 columns]

# %%
royal_per_genre_median = df_genre.iloc[:, 2:].apply(lambda x:np.median(df_genre['revenue'][x>0]))
royal_per_genre_median = royal_per_genre_median.sort_values()

# %%
# Median Royalties paid to UMW by genre in France (IMDB, December 2019)

plt.style.use('dark_background')
royal_per_genre_median.plot.barh(color = 'orange', figsize = (10, 15))
plt.title('Median Royalties paid to UMW by genre in France', fontsize = 30, fontweight = 20)
#plt.yticks(np.arange(50),imdb_boxoffice.Title[0:49], rotation=0)
plt.ylabel('Genre')
plt.xlabel('Median Royalties')
plt.show()

# %%
royal_per_actor_median = df_cast.iloc[:, 2:].apply(lambda x:np.median(df_cast['revenue'][x>0]))
royal_per_actor_median = royal_per_actor_median.sort_values(ascending=False)

# %%
royal_per_actor_median.head(50)
# Out:
# Ioan Gruffudd         33621.100000
# Martin Starr          33621.100000
# Anthony Mackie        33621.100000
# Chris Evans           33621.100000
# Topher Grace          33621.100000
# Michelle Monaghan     33621.100000
# Jacques Morel         28189.230000
# Zac Efron             25528.920000
# Imogen Poots          25528.920000
# Miles Teller          25528.920000
# Michael B. Jordan     25528.920000
# Mackenzie Davis       25528.920000
# Erika Christensen     25286.410585
# Robert Forter         25286.410585
# Robert Forster        25286.410585
# Faye Dunaway          25286.410585
# Hichem Yacoubi        23235.733033
# Salim Kechiouche      23235.733033
# Abel Jafri            23235.733033
# Jo Prestia            23235.733033
# Claudio Moneta        23074.660000
# Dylan McDermott       23000.330000
# Selena Gomez          23000.330000
# Ashley Rickards       23000.330000
# Mary-Louise Parker    23000.330000
# Jason Lee             23000.330000
# Elisabeth Shue        23000.330000
# Nat Wolff             23000.330000
# Noriaki Sugiyama      22789.060000
# Kokoro Kikuchi        22789.060000
# Yuko Sanpei           22789.060000
# Inma Sancho           20882.110000
# Miri Giner            20882.110000
# Edu Borja             20882.110000
# Silvia Cabrera        20882.110000
# Micheline Dax         20681.790000
# Roger Carel           20506.175000
# Luke Wilson           19916.220000
# Victor Garber         19622.450000
# Michelle Forbes       19622.450000
# Alexa PenaVega        19622.450000
# Robbie Amell          19622.450000
# Billy Crudup          19118.990000
# Tony Roberts          19118.990000
# Laura Clery           19118.990000
# Jason Bateman         19118.990000
# Olivia Wilde          19118.990000
# Alexandra Neil        19118.990000
# Jenny Slate           19118.990000
# Aimee Teegarden       18734.392144
# dtype: float64
