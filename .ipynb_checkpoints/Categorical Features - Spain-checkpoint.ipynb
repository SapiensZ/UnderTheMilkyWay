# %%
# basic operations
import numpy as np
import pandas as pd


# for visualizations
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
# import csv file
df = pd.read_csv("UMW_IT_reduced.csv", sep=",")
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (19,20,33,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
#Define columns of interest
cols_1 = ['original_title', 'royalties_paid_eur']
cols_2 = ['cast', 'genre']
cols = cols_1 + cols_2

# %%
#Group by movies and transform labels
df_revenue = df[cols].groupby('original_title')['royalties_paid_eur'].sum()
df_count = df[cols].groupby('original_title')['royalties_paid_eur'].count()

df_movie = df[['original_title'] + cols_2].drop_duplicates()
df_movie = df_movie.fillna('None')
df_movies = []
for col in cols_2:
    mlb = MultiLabelBinarizer()
    df_movie[col] = df_movie[col].str.split(', ')
    temp1 = pd.DataFrame({'revenue':df_revenue, 'count':df_count})
    temp2 = pd.DataFrame(mlb.fit_transform(df_movie[col]), columns=mlb.classes_, index=df_movie['original_title'])
    temp = temp1.join(temp2)
    df_movies.append(temp)

# %%
# One-hot dataframe with all starred actors
df_cast = df_movies[0]
df_cast
# Out:
#                                             revenue  count  -  \
# original_title
#  L'amant double                             1905.71    624  0
#  Mirai no Mirai                             1785.41    465  0
# (M)uchenik                                   589.07    272  0
# 10 Items or Less                             452.83    307  0
# 10 Milliarden - wie werden wir alle satt?    854.04    365  0
# ...                                             ...    ... ..
# [REC]Â³ GÃ©nesis                            1123.33    535  0
# jOBS                                       47198.18  17880  0
# Â¿QuÃ© he hecho yo para merecer esto!!      1090.64    642  0
# Ãtame!                                      779.58    460  0
# Ãtez-moi d'un doute                          48.36     19  0
#
#                                            20 inhabitants from L'Aquila  \
# original_title
#  L'amant double                                                       0
#  Mirai no Mirai                                                       0
# (M)uchenik                                                            0
# 10 Items or Less                                                      0
# 10 Milliarden - wie werden wir alle satt?                             0
# ...                                                                 ...
# [REC]Â³ GÃ©nesis                                                      0
# jOBS                                                                  0
# Â¿QuÃ© he hecho yo para merecer esto!!                                0
# Ãtame!                                                               0
# Ãtez-moi d'un doute                                                  0
#
#                                            50 Cent  ADAM ARBAB  ALEC GUINNES  \
# original_title
#  L'amant double                                  0           0             0
#  Mirai no Mirai                                  0           0             0
# (M)uchenik                                       0           0             0
# 10 Items or Less                                 0           0             0
# 10 Milliarden - wie werden wir alle satt?        0           0             0
# ...                                            ...         ...           ...
# [REC]Â³ GÃ©nesis                                 0           0             0
# jOBS                                             0           0             0
# Â¿QuÃ© he hecho yo para merecer esto!!           0           0             0
# Ãtame!                                          0           0             0
# Ãtez-moi d'un doute                             0           0             0
#
#                                            ALEXIS GEORGOULIS  ALICJA BACHLEDA  \
# original_title
#  L'amant double                                            0                0
#  Mirai no Mirai                                            0                0
# (M)uchenik                                                 0                0
# 10 Items or Less                                           0                0
# 10 Milliarden - wie werden wir alle satt?                  0                0
# ...                                                      ...              ...
# [REC]Â³ GÃ©nesis                                           0                0
# jOBS                                                       0                0
# Â¿QuÃ© he hecho yo para merecer esto!!                     0                0
# Ãtame!                                                    0                0
# Ãtez-moi d'un doute                                       0                0
#
#                                            ALLEN DANZINGER  ...  \
# original_title                                              ...
#  L'amant double                                          0  ...
#  Mirai no Mirai                                          0  ...
# (M)uchenik                                               0  ...
# 10 Items or Less                                         0  ...
# 10 Milliarden - wie werden wir alle satt?                0  ...
# ...                                                    ...  ...
# [REC]Â³ GÃ©nesis                                         0  ...
# jOBS                                                     0  ...
# Â¿QuÃ© he hecho yo para merecer esto!!                   0  ...
# Ãtame!                                                  0  ...
# Ãtez-moi d'un doute                                     0  ...
#
#                                            Ãlex GarcÃ­a  Ãngela del Salto  \
# original_title
#  L'amant double                                        0                  0
#  Mirai no Mirai                                        0                  0
# (M)uchenik                                             0                  0
# 10 Items or Less                                       0                  0
# 10 Milliarden - wie werden wir alle satt?              0                  0
# ...                                                  ...                ...
# [REC]Â³ GÃ©nesis                                       0                  0
# jOBS                                                   0                  0
# Â¿QuÃ© he hecho yo para merecer esto!!                 0                  0
# Ãtame!                                                0                  0
# Ãtez-moi d'un doute                                   0                  0
#
#                                            Ãmilie Dequenne  Ãtienne Galloy  \
# original_title
#  L'amant double                                           0                0
#  Mirai no Mirai                                           0                0
# (M)uchenik                                                0                0
# 10 Items or Less                                          0                0
# 10 Milliarden - wie werden wir alle satt?                 0                0
# ...                                                     ...              ...
# [REC]Â³ GÃ©nesis                                          0                0
# jOBS                                                      0                0
# Â¿QuÃ© he hecho yo para merecer esto!!                    0                0
# Ãtame!                                                   0                0
# Ãtez-moi d'un doute                                      0                0
#
#                                            Ãlafur Darri Ãlafsson  \
# original_title
#  L'amant double                                                  0
#  Mirai no Mirai                                                  0
# (M)uchenik                                                       0
# 10 Items or Less                                                 0
# 10 Milliarden - wie werden wir alle satt?                        0
# ...                                                            ...
# [REC]Â³ GÃ©nesis                                                 0
# jOBS                                                             0
# Â¿QuÃ© he hecho yo para merecer esto!!                           0
# Ãtame!                                                          0
# Ãtez-moi d'un doute                                             0
#
#                                            Ãscar Jaenada  \
# original_title
#  L'amant double                                         0
#  Mirai no Mirai                                         0
# (M)uchenik                                              0
# 10 Items or Less                                        0
# 10 Milliarden - wie werden wir alle satt?               0
# ...                                                   ...
# [REC]Â³ GÃ©nesis                                        0
# jOBS                                                    0
# Â¿QuÃ© he hecho yo para merecer esto!!                  0
# Ãtame!                                                 0
# Ãtez-moi d'un doute                                    0
#
#                                            ÃrÃ¶stur LeÃ³ Gunnarsson  \
# original_title
#  L'amant double                                                    0
#  Mirai no Mirai                                                    0
# (M)uchenik                                                         0
# 10 Items or Less                                                   0
# 10 Milliarden - wie werden wir alle satt?                          0
# ...                                                              ...
# [REC]Â³ GÃ©nesis                                                   0
# jOBS                                                               0
# Â¿QuÃ© he hecho yo para merecer esto!!                             0
# Ãtame!                                                            0
# Ãtez-moi d'un doute                                               0
#
#                                            ã¢ãã«ããÂ·ã­ã¼ãº  \
# original_title
#  L'amant double                                                     0
#  Mirai no Mirai                                                     0
# (M)uchenik                                                          0
# 10 Items or Less                                                    0
# 10 Milliarden - wie werden wir alle satt?                           0
# ...                                                               ...
# [REC]Â³ GÃ©nesis                                                    0
# jOBS                                                                0
# Â¿QuÃ© he hecho yo para merecer esto!!                              0
# Ãtame!                                                             0
# Ãtez-moi d'un doute                                                0
#
#                                            ã­ã¦ã§ãã«Â·ã¤ã¸ã§ãã©ã¼  \
# original_title
#  L'amant double                                                              0
#  Mirai no Mirai                                                              0
# (M)uchenik                                                                   0
# 10 Items or Less                                                             0
# 10 Milliarden - wie werden wir alle satt?                                    0
# ...                                                                        ...
# [REC]Â³ GÃ©nesis                                                             0
# jOBS                                                                         0
# Â¿QuÃ© he hecho yo para merecer esto!!                                       0
# Ãtame!                                                                      0
# Ãtez-moi d'un doute                                                         0
#
#                                            ã¿ã³ãã£Â·ãã¥ã¼ãã³
# original_title
#  L'amant double                                                        0
#  Mirai no Mirai                                                        0
# (M)uchenik                                                             0
# 10 Items or Less                                                       0
# 10 Milliarden - wie werden wir alle satt?                              0
# ...                                                                  ...
# [REC]Â³ GÃ©nesis                                                       0
# jOBS                                                                   0
# Â¿QuÃ© he hecho yo para merecer esto!!                                 0
# Ãtame!                                                                0
# Ãtez-moi d'un doute                                                   0
#
# [1777 rows x 4734 columns]

# %%
# One-hot dataframe with all represented genres
df_genre = df_movies[1]
df_genre
# Out:
#                                             revenue  count  \
# original_title
#  L'amant double                             1905.71    624
#  Mirai no Mirai                             1785.41    465
# (M)uchenik                                   589.07    272
# 10 Items or Less                             452.83    307
# 10 Milliarden - wie werden wir alle satt?    854.04    365
# ...                                             ...    ...
# [REC]Â³ GÃ©nesis                            1123.33    535
# jOBS                                       47198.18  17880
# Â¿QuÃ© he hecho yo para merecer esto!!      1090.64    642
# Ãtame!                                      779.58    460
# Ãtez-moi d'un doute                          48.36     19
#
#                                            Action & Adventure  African  Anime  \
# original_title
#  L'amant double                                             0        0      0
#  Mirai no Mirai                                             1        0      1
# (M)uchenik                                                  0        0      0
# 10 Items or Less                                            0        0      0
# 10 Milliarden - wie werden wir alle satt?                   0        0      0
# ...                                                       ...      ...    ...
# [REC]Â³ GÃ©nesis                                            0        0      0
# jOBS                                                        0        0      0
# Â¿QuÃ© he hecho yo para merecer esto!!                      0        0      0
# Ãtame!                                                     0        0      0
# Ãtez-moi d'un doute                                        0        0      0
#
#                                            Classics  Comedy  Concert Films  \
# original_title
#  L'amant double                                   0       0              0
#  Mirai no Mirai                                   0       0              0
# (M)uchenik                                        0       0              0
# 10 Items or Less                                  0       1              0
# 10 Milliarden - wie werden wir alle satt?         0       0              0
# ...                                             ...     ...            ...
# [REC]Â³ GÃ©nesis                                  0       0              0
# jOBS                                              0       0              0
# Â¿QuÃ© he hecho yo para merecer esto!!            0       1              0
# Ãtame!                                           0       1              0
# Ãtez-moi d'un doute                              0       1              0
#
#                                            Crime  Documentary  ...  \
# original_title                                                 ...
#  L'amant double                                0            0  ...
#  Mirai no Mirai                                0            0  ...
# (M)uchenik                                     0            0  ...
# 10 Items or Less                               0            0  ...
# 10 Milliarden - wie werden wir alle satt?      0            1  ...
# ...                                          ...          ...  ...
# [REC]Â³ GÃ©nesis                               0            0  ...
# jOBS                                           0            0  ...
# Â¿QuÃ© he hecho yo para merecer esto!!         0            0  ...
# Ãtame!                                        0            0  ...
# Ãtez-moi d'un doute                           0            0  ...
#
#                                            Sci-Fi & Fantasy  Short Films  \
# original_title
#  L'amant double                                           0            0
#  Mirai no Mirai                                           1            0
# (M)uchenik                                                0            0
# 10 Items or Less                                          0            0
# 10 Milliarden - wie werden wir alle satt?                 0            0
# ...                                                     ...          ...
# [REC]Â³ GÃ©nesis                                          0            0
# jOBS                                                      0            0
# Â¿QuÃ© he hecho yo para merecer esto!!                    0            0
# Ãtame!                                                   0            0
# Ãtez-moi d'un doute                                      0            0
#
#                                            Special Interest  Sports  Suspense  \
# original_title
#  L'amant double                                           0       0         0
#  Mirai no Mirai                                           0       0         0
# (M)uchenik                                                0       0         0
# 10 Items or Less                                          0       0         0
# 10 Milliarden - wie werden wir alle satt?                 1       0         0
# ...                                                     ...     ...       ...
# [REC]Â³ GÃ©nesis                                          0       0         0
# jOBS                                                      0       0         0
# Â¿QuÃ© he hecho yo para merecer esto!!                    0       0         0
# Ãtame!                                                   0       0         0
# Ãtez-moi d'un doute                                      0       0         0
#
#                                            Thriller  Turkish  Urban  War  \
# original_title
#  L'amant double                                   1        0      0    0
#  Mirai no Mirai                                   0        0      0    0
# (M)uchenik                                        1        0      0    0
# 10 Items or Less                                  0        0      0    0
# 10 Milliarden - wie werden wir alle satt?         0        0      0    0
# ...                                             ...      ...    ...  ...
# [REC]Â³ GÃ©nesis                                  0        0      0    0
# jOBS                                              0        0      0    0
# Â¿QuÃ© he hecho yo para merecer esto!!            0        0      0    0
# Ãtame!                                           0        0      0    0
# Ãtez-moi d'un doute                              0        0      0    0
#
#                                            Western
# original_title
#  L'amant double                                  0
#  Mirai no Mirai                                  0
# (M)uchenik                                       0
# 10 Items or Less                                 0
# 10 Milliarden - wie werden wir alle satt?        0
# ...                                            ...
# [REC]Â³ GÃ©nesis                                 0
# jOBS                                             0
# Â¿QuÃ© he hecho yo para merecer esto!!           0
# Ãtame!                                          0
# Ãtez-moi d'un doute                             0
#
# [1777 rows x 44 columns]

# %%
royal_per_genre_median = df_genre.iloc[:, 2:].apply(lambda x:np.median(df_genre['revenue'][x>0]))
royal_per_genre_median = royal_per_genre_median.sort_values()

# %%
# Median Royalties paid to UMW by genre in Italy (IMDB, December 2019)

plt.style.use('dark_background')
royal_per_genre_median.plot.barh(color = 'orange', figsize = (10, 15))
plt.title('Median Royalties paid to UMW by genre in Italy', fontsize = 30, fontweight = 20)
#plt.yticks(np.arange(50),imdb_boxoffice.Title[0:49], rotation=0)
plt.ylabel('Genre')
plt.xlabel('Median Royalties')
plt.show()

# %%
royal_per_actor_median = df_cast.iloc[:, 2:].apply(lambda x:np.median(df_cast['revenue'][x>0]))
royal_per_actor_median = royal_per_actor_median.sort_values(ascending=False)

# %%
royal_per_actor_median.head(50)
# Out:
# Riccardo Scamarcio      82613.990
# Shailene Woodley        75745.190
# Adrianne Palicki        73274.830
# Michael Keaton          69299.870
# Linda Cardellini        63331.940
# ZoÃ« Kravitz            58967.820
# Sebastian Maniscalco    57364.010
# Dimiter D. Marinov      57364.010
# Carly Rae Jepsen        50949.770
# Federico Russo          50949.770
# Maddie Ziegler          50949.770
# Stefano Ambrogi         50074.290
# Ilenia Pastorelli       50074.290
# Luca Marinelli          50074.290
# Claudio Santamaria      50074.290
# Dave Franco             49899.540
# Lukas Haas              47198.180
# Josh Gad                47198.180
# Ben Winshaw             47071.970
# Tom Hanks               47071.970
# Doona Bae               47071.970
# James D'Arcy            47071.970
# Halle Berry             47071.970
# Matthew Goode           46115.085
# Benedict Cumberbatch    37579.315
# Michael Nyqvist         36826.420
# Rory Kinnear            36163.880
# Angela Bassett          34993.795
# Peter Facinelli         34157.060
# Patrick                 32715.600
# Patrick Wilson          32715.600
# Liam                    32715.600
# Vera                    32715.600
# Jonathan Banks          32715.600
# Vera Farmiga            32715.600
# Hugh Bonneville         32374.380
# MichaÃ«l Youn           32258.080
# Connie Nielsen          31605.000
# Mahershala Ali          31261.855
# Viggo Mortensen         30188.175
# Asa Butterfield         30118.540
# Hailee Steinfeld        30118.540
# Samuel Joslin           29146.260
# Oaklee Pendergast       29146.260
# Richard Pyros           29093.610
# Jacob Warner            29093.610
# David Wenham            28092.460
# Sunny Pawar             28092.460
# Abhishek Bharate        28092.460
# MicheÃ¡l Richardson     28033.430
# dtype: float64
